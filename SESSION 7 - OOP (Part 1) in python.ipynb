# %% [markdown]
# #### OOP (Object-Oriented Programming)

# %% [raw]
# 1.Object-oriented programming (OOP) is a programming paradigm based on the concept of "objects".
#
# 2.The object contains both data and code: Data in the form of properties (often known as attributes), and code, in the form of methods (actions object can perform).
#
# 3.An object-oriented paradigm is to design the program using classes and objects. Python programming language supports different programming approaches like functional programming, modular programming.
#
# 4.One of the popular approaches is object-oriented programming (OOP) to solve a programming problem is by creating objects
#
# 5.Python OOP concepts
#   An object has the following two characteristics:
#   >Attribute
#   >Behavior
#   Object Oriented Programming in Python :
#
#   For example, A Car is an object, as it has the following properties:
#     name, price, color as attributes
#     breaking, acceleration as behavior
#     One important aspect of OOP in Python is to create reusable code using the concept of inheritance. This concept is also known as DRY (Don't Repeat Yourself).
#
# 6.OOP contain certain principles that are shown in diagram.

# %% [markdown]
# ![oop_concepts.png](attachment:oop_concepts.png)

# %% [markdown]
# #### What is a Class and Objects in Python?

# %% [markdown]
# ##### Class :

# %% [raw]
# 1.The class is a user-defined data structure that binds the data members and methods into a single unit.
#
# 2.Class is a blueprint to create a object or code template for object creation or set of rules and it is followed by object . Using a class, you can create as many objects as you want.
#
# For Example,
# Consider we launch Data Science Mentorship Course and we consider that course as 'class'.
# In courese we set rules like Mon to Fri lectures are free and Saturday is paid so this bluprint of the course.
# When students are enroll in the program now we can access the mentorship program means each student who is actually part of the this program it is 'object' of program.
# Here ,
# class = Mentorship program
# students = object
#
# Other Example,
# car = ['toyota','ford','tata']
# car > class
# ['toyota','ford','tata'] > object
#
# 3.In python all datatype are all classes and when you create variable of datatype then it is called as object.
#
# 4.A class contains the properties/attribute and function/behavior of the object. attributes represent variables, and the methods represent behaviors. Hence class includes both variables and methods.

# %% [markdown]
# ##### Object :

# %% [raw]
# 1.An object is an instance of a class.
#
# 2.It is a collection of attributes (variables) and methods. We use the object of a class to perform actions.
#
# 3.Object represents the base class from where all classes in python are derived.
#
# 4.Objects have two characteristics:
# They have states and behaviors (object has attributes and methods attached to it)
# Attributes represent its state, and methods represent its behavior. Using its methods, we can modify its state.
#
# 5.Syntax
# <object-name> = <class-name>(<arguments>)

# %% [markdown]
# #### Create a Class in Python :

# %% [raw]
# In Python, class is defined by using the class keyword. The syntax to create a class is given below.
#
# Syntax:
# class class_name:
#     '''This is a docstring. I have created a new class'''
#     <statement 1>
#     <statement 2>
#     .
#     .
#     <statement N>
#
# class_name: It is the name of the class
# Docstring: It is the first string inside the class and has a brief description of the class. Although not mandatory, this is highly recommended.
# statements: Attributes and methods

# %%
# Ex.

class Atm:
    
    #constructor
    def __init__(self):
        self.pin = ''
        self.balance = 0

# %%
# creating object of class
obj = Atm()

# cheking object type
print(type(obj))
# Out:
# <class '__main__.Atm'>
