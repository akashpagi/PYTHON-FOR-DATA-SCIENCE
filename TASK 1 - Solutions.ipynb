# %% [markdown]
# ![TASK%201-2.png](attachment:TASK%201-2.png)

# %%
# Q1.Solution :
print("Data",'Science','Membership','Program','By','CampusX', sep='-',end='')
# Out:
# Data-Science-Membership-Program-By-CampusX

# %%
# Q2. Solution :
# formula : si = (p*r*t)/100

p = int(input('Enter principle amount :'))
r = float(input('Enter rate of interest :'))
t = int(input('Enter time period (in year) :'))

SI = (p * r * t)/100

print('simple interest is',(int(SI)),'.')
# Out:
# Enter principle amount :20000
# Enter rate of interest :4
# Enter time period (in year) :2
# simple interest is 1600 .

# %%
# Q3. Solution :
# formula : f = ((c * 1.8) + 32)
c = float(input('Enter the temperature (C°):'))
f = ( (c * 1.8 )+32)
print(c,'C° conveted into',f,'F°')

#extra
# formula : c = ((f - 32) / 1.8)
f = float(input('Enter the temperature (F°):'))
c = (((f - 32) / 1.8))
print(f,'F° conveted into',c,'C°')
# Out:
# Enter the temperature (C°):30
# 30.0 C° conveted into 86.0 F°
# Enter the temperature (F°):86
# 86.0 F° conveted into 30.0 C°
