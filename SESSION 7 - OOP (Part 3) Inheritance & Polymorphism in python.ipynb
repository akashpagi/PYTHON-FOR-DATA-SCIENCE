# %% [markdown]
# ### SESSION 7 - OOP (Part 3) Inheritance & Polymorphism in python

# %% [markdown]
# #### Class Relationships :

# %% [raw]
# - Aggregation
# - Inheritance

# %% [markdown]
# ##### Aggregation (Has A relationship) :

# %% [raw]
# - It has relation
# - One class owns the other class
# - Ex Customer class has a Address class
# - In below code , when you perform aggregation we can't access private varibles directly of own class, as a solution you have to us getter method

# %%
#Ex for aggregation
class Customer:  
    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address
    
    # calling address Address class
    def print_address(self):
        print(self.address._Address__city,self.address.pin,self.address.state)
        
    # adding method in customer to edit the class
    def edit_profile(self,new_name,new_city,new_pin,new_state):
        self.name = new_name
        self.address.edit_address(new_city,new_pin,new_state)
        
        
# Creating aggregation class and it is use by Customer class  
class Address:
    def __init__(self,city,pin,state):
        self.__city = city
        self.pin = pin
        self.state = state
        
    # getter method for accessing private variable of address class by Customer  
    def get_city(self):
        return self.__city
    
    # Adding method to edit the profile
    def edit_address(self,new_city,new_pin,new_state):
        self.__city = new_city
        self.pin = new_pin
        self.state = new_state

addrs = Address(5164,'MUMBAI',401208)        
cus = Customer('Akash',21,addrs)
    
cus.print_address()
cus.edit_profile('ankit','mumbai',111111,'maharashtra')
cus.print_address()
# Out:
# 5164 MUMBAI 401208
# mumbai 111111 maharashtra

# %% [markdown]
# #### Aggregation class diagram :

# %% [markdown]
# ![class%20diagram%20of%20aggregation.png](attachment:class%20diagram%20of%20aggregation.png)

# %% [markdown]
# #### Inheritance :

# %% [raw]
# - The process of inheriting the properties of the parent class into a child class is called inheritance.
#
# - The existing class is called a base class or parent class and the new class is called a subclass or child class or derived class.
#
# - In Object-oriented programming, inheritance is an important aspect. The main purpose of inheritance is the reusability of code
#
# - In inheritance, the child class acquires all the data members, properties, and functions from the parent class. Also, a child class can also provide its specific implementation to the methods of the parent class.

# %% [markdown]
# ##### Inheritance Udemy Example :

# %% [markdown]
# ![inheritance%20udemy%20example.png](attachment:inheritance%20udemy%20example.png)

# %% [markdown]
# ##### Inheritance symbol in class diagram :

# %% [markdown]
# ![Inheritances%20Symbol%20in%20class%20diagram-2.png](attachment:Inheritances%20Symbol%20in%20class%20diagram-2.png)

# %%
# Example

# parent
class User:

    def __init__(self):
        self.name = 'Goku'

    def login(self):
        print('login')

# child
class Student(User):
    def enroll(self):
        print('enroll into the course')

u = User()
s = Student()

print(s.name)
s.login()
s.enroll()
# Out:
# Goku
# login
# enroll into the course

# %% [markdown]
# ##### What gets inherited?

# %% [raw]
# Constructor
# Non Private Attributes
# Non Private Methods

# %%
# constructor example 1

# Phone is parent class
class Phone:
    def __init__(self,price, brand, camera):
        print('Inside the phone constructor')
        self.name = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print('Buying a phone')

# SmartPhone is Child class
class SmartPhone(Phone):
    pass

s = SmartPhone(30000,'Noting', 13)
s.buy()
# Out:
# Inside the phone constructor
# Buying a phone

# %%
# constructor example 2

# Phone is parent class
class Phone:
    def __init__(self,price, brand, camera):
        print('Inside the phone constructor')
        self.price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print('Buying a phone')

# SmartPhone is Child class
class SmartPhone(Phone):
    def __init__(self, os, ram):
        self.os = os
        self.ram = ram
        print('Inside the SamrtPhone function constructor')

s = SmartPhone('Anroid', 16)
# Out:
# Inside the SamrtPhone function constructor

# %%
# child can't access private members and private method of the class 

# Phone is parent class
class Phone:
    def __init__(self,price, brand, camera):
        print('Inside the phone constructor')
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def __Show(self):
        print(self.__price)

# SmartPhone is Child class
class SmartPhone(Phone):
    def Check(self):
        print(self.__price)

s = SmartPhone(30000,'Nothing', 16)
#print(s.brand)
#s.Check()

# Here we can't access private method
s.__Show()
# Out:
# Inside the phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [21], line 24
#      19 s = SmartPhone(30000,'Nothing', 16)
#      20 #print(s.brand)
#      21 #s.Check()
#      22
#      23 # Here we can't access private method
# ---> 24 s.__Show()
#
# AttributeError: 'SmartPhone' object has no attribute '__Show'

# %% [markdown]
# ###### Some more examples on inheritence with private members and private methods :

# %%
# Ex-1.Accessing parent private attribute with getter method 
class Parent: 
    def __init__(self,num): 
        self.__num=num 
    def get_num(self): 
            return self.__num 
class Child(Parent): 
    def show(self): 
        print("This is in child class") 
son=Child(100) 
print(son.get_num()) 
son.show()
# Out:
# 100
# This is in child class

# %%
# Ex-2.If Child has constructor,parent constructor not called
class Parent:
    def __init__(self,num):
        self.__num=num
    def get_num(self):
        return self.__num

class Child(Parent):
    def __init__(self,val,num):
        self.__val=val
    def get_val(self):
        return self.__val
        
son=Child(100,10)
print("Parent: Num:",son.get_num())
print("Child: Val:",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [25], line 15
#      12         return self.__val
#      14 son=Child(100,10)
# ---> 15 print("Parent: Num:",son.get_num())
#      16 print("Child: Val:",son.get_val())
#
# Cell In [25], line 6, in Parent.get_num(self)
#       5 def get_num(self):
# ----> 6     return self.__num
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
# Ex-3.If Child don't have constructor,parent constructor is called 
class A:
    def __init__(self):
        self.var1=100 # static value is 100

    def display1(self,var1):
        #self.var1 = var1 # output is 200
        print("class A :", self.var1)
class B(A):
  
    def display2(self,var1):
        print("class B :", self.var1)

obj=B()
obj.display1(200) # output is 100
# Out:
# class A : 100

# %% [markdown]
# #### Method Overriding :

# %% [raw]
# 1.In inheritance, all members available in the parent class are by default available in the child class.
#
# 2. If the child class does not satisfy with parent class implementation, then the child class is allowed to redefine that method by extending additional functions in the child class. This concept is called method overriding.
#
# 3.When a child class method has the same name, same parameters, and same return type as a method in its superclass, then the method in the child is said to override the method in the parent class.

# %%
# Method Overriding  Ex.
class Phone:
    def __init__(self, price, brand, camera):
        print('Inside phone constructor')
        self.__price = price
        self.band = brand
        self.camera = camera
    def buy(self):
        print('buy() method of Phone : Buying a phone')
        
class SmartPhone(Phone):
    def buy(self):
        print('buy() method of SmartPhone: Buying a smartphone') 
        # child class method execute in method overriding

s = SmartPhone(60000,'Asus Zenfone 9',13)
s.buy()
# Out:
# Inside phone constructor
# buy() method of SmartPhone: Buying a smartphone

# %% [markdown]
# #### Super() Keyword in python :

# %% [raw]
# 1.The super() function is used to give access to methods and properties of a parent or sibling class.
#
# 2.The super() function returns an object that represents the parent class.
#
# 3.Super() function use inside the classes and method of child classes.
#
# 4. Using Super() you can access only methods means you can't access parent instance varibles (data).

# %%
# Ex.
class Phone:
    def __init__(self, price, brand, camera):
        print('Inside phone constructor')
        self.__price = price
        self.band = brand
        self.camera = camera
    def buy(self):
        print('Buying a phone')
        
class SmartPhone(Phone):
    def buy(self):
        print('Buying a smartphone') 
        # calling parent class buy method in SamrtPhone method 
        # syntax
        super().buy()

s = SmartPhone(60000,'Asus Zenfone 9',13)
s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# super() with constuctor
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, price, brand, camera, os, ram):
        print('Inside smartphone constructor')
        super().__init__(price, brand, camera)
        
        self.os = os
        self.ram = ram
        print ("Inside smartphone constructor")

s=SmartPhone(20000, "Samsung", 12, "Android", 2)

print(s.os)
print(s.brand)
# Out:
# Inside smartphone constructor
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung

# %% [markdown]
# #### Inheritance summary :

# %% [raw]
# A class can inherit from another class.
#
# Inheritance improves code reuse
#
# Constructor, attributes, methods get inherited to the child class
#
# The parent has no access to the child class
#
# Private properties of parent are not accessible directly in child class
#
# Child class can override the attributes or methods. This is called method overriding
#
# super() is an inbuilt function which is used to invoke the parent class methods and constructor

# %% [markdown]
# #### Types Of Inheritance :

# %% [raw]
# In Python, based upon the number of child and parent classes involved, there are five types of inheritance.
#
# The type of inheritance are listed below:
# 1.Single inheritance
#
# 2.Multiple Inheritance
#
# 3.Multilevel inheritance
#
# 4.Hierarchical Inheritance
#
# 5.Hybrid Inheritance
